# %%
import pandas as pd
import os

df = pd.read_csv("sales_data.xls")

# %%
df.head()
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 1        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 3       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
# ...

# %%
df.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
df.shape
# Out:
# (578320, 12)

# %%
df.dtypes
# Out:
# customer_id        object
# device_id          object
# item_id             int64
# line_item_id        int64
# order_id           object
# event_id            int64
# event_timestamp    object
# quantity            int64
# currency           object
# checked_out_at     object
# status             object
# location           object
# dtype: object

# %%
df.describe()
# Out:
#              item_id   line_item_id       event_id       quantity
# count  578320.000000  578320.000000  578320.000000  578320.000000
# mean        7.995741   19034.444880   88235.379821       3.009861
# std         4.322902    9153.541683   42541.874688       1.406914
# min         1.000000    3201.000000   14786.000000       1.000000
# 25%         4.000000   11108.000000   51318.000000       2.000000
# 50%         8.000000   19067.000000   88373.000000       3.000000
# 75%        12.000000   26960.000000  125003.000000       4.000000
# max        15.000000   34941.000000  161960.000000       5.000000

# %%
df.loc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
df.iloc[[0,2,4,6]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14787
#
#               event_timestamp  quantity currency              checked_out_at  \
# 0  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
df.loc[[0,2,4,6],['customer_id','device_id','item_id']]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 2        9
# 4        6
# 6        4

# %%
df.iloc[[0,2,4,6],[0,1,2,3]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id
# 0        4          3201
# 2        9          3203
# 4        6          3205
# 6        4          3201

# %%
df.iloc[::]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.loc[:]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.loc[-1:]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.loc[0:4,'customer_id':'item_id']
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 1        5
# 2        9
# 3       12
# 4        6

# %%
df.iloc[0:4,0:4]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id
# 0        4          3201
# 1        5          3202
# 2        9          3203
# 3       12          3204

# %%
df.iloc[0:-1,0:4]
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578314  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.iloc[-1:,0:4]
# Out:
#                                  customer_id  \
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id
# 578319  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941

# %%
df.iloc[0:-1,1:4]
# Out:
#                                    device_id  item_id  line_item_id
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...                                      ...      ...           ...
# 578314  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# 578315  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# 578316  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
# 578317  74bb4936-9890-421b-a62a-ee544191fa1e        1         34941
# 578318  74bb4936-9890-421b-a62a-ee544191fa1e        4         34940
#
# [578319 rows x 3 columns]

# %%
df.set_index("location", inplace=True)

# %%
df.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
df.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578320)

# %%
df.index.unique()
# Out:
# Index(['Saint Helena', 'Djibouti', 'Ecuador', 'Mali', 'Grenada',
#        'United States Minor Outlying Islands', 'Aruba', 'Germany',
#        'Saint Pierre and Miquelon', 'Sudan',
#        ...
#        'Brazil', 'French Southern Territories', 'Gambia', 'Pakistan',
#        'Slovenia', 'Zambia', 'United Kingdom', 'United Arab Emirates',
#        'Kyrgyz Republic', 'Namibia'],
#       dtype='object', name='location', length=243)

# %%
df.index.nunique()
# Out:
# 243

# %%
df.index.unique().sort_values()
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica (the territory South of 60 deg S)',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=243)

# %%
df.index.value_counts().sort_values().head(10)
# Out:
# location
# Uruguay                     734
# Italy                       783
# Austria                     921
# Malaysia                   1037
# Chad                       1082
# Taiwan                     1122
# Cocos (Keeling) Islands    1168
# Honduras                   1195
# Saint Kitts and Nevis      1201
# Greece                     1214
# Name: count, dtype: int64

# %%
df.index.value_counts().sort_values().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='location'>

# %%
df.index.value_counts().sort_values(ascending=False).head(10)
# Out:
# location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
df.index.value_counts().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='location'>

# %%
df.index.value_counts().sort_values(ascending=False).head(50).plot(kind="bar", figsize=(10,5))
# Out:
# <Axes: xlabel='location'>

# %%
df.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
df.index.value_counts().sort_values().unique()
# Out:
# array([ 734,  783,  921, 1037, 1082, 1122, 1168, 1195, 1201, 1214, 1216,
#        1225, 1229, 1352, 1370, 1379, 1384, 1390, 1394, 1403, 1404, 1421,
#        1447, 1493, 1522, 1533, 1541, 1550, 1586, 1588, 1601, 1608, 1613,
#        1638, 1662, 1665, 1666, 1674, 1682, 1683, 1689, 1695, 1712, 1720,
#        1727, 1733, 1735, 1742, 1743, 1749, 1751, 1757, 1777, 1785, 1794,
#        1795, 1804, 1823, 1829, 1830, 1838, 1842, 1846, 1849, 1858, 1861,
#        1864, 1875, 1877, 1878, 1879, 1884, 1894, 1905, 1920, 1930, 1934,
#        1939, 1973, 1988, 1989, 1995, 2003, 2007, 2021, 2035, 2036, 2037,
#        2061, 2077, 2081, 2103, 2105, 2116, 2135, 2138, 2160, 2198, 2199,
#        2204, 2211, 2215, 2244, 2245, 2250, 2288, 2293, 2305, 2330, 2340,
#        2351, 2361, 2371, 2382, 2385, 2396, 2401, 2413, 2421, 2422, 2435,
#        2449, 2467, 2471, 2476, 2484, 2489, 2491, 2501, 2506, 2511, 2513,
#        2521, 2526, 2538, 2547, 2561, 2563, 2564, 2565, 2567, 2579, 2583,
# ...

# %%
df.groupby("location")["quantity"].sum().sort_values()
# Out:
# location
# Uruguay       1985
# Italy         2448
# Austria       2787
# Chad          3058
# Barbados      3278
#              ...
# Panama       11942
# Jersey       12447
# Mauritius    13452
# Argentina    13475
# Korea        20826
# Name: quantity, Length: 243, dtype: int64

# %%
df.loc["Nigeria"]
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
df[df["customer_id"] == "916401c0-8d4c-40b3-91d3-2adf0d6d814f"]
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
df["customer_id"].nunique()
# Out:
# 4594

# %%
df["device_id"].nunique()
# Out:
# 4594

# %%
df["customer_id"].value_counts().sort_values(ascending=False).head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='customer_id'>

# %%
call = (df["customer_id"] == "916401c0-8d4c-40b3-91d3-2adf0d6d814f")

# %%
df[call].head()
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
#
#                                       order_id  event_id  \
# location
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# ...

# %%
df.loc[call].head(1)
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
#
#                                       order_id  event_id  \
# location
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
#
#                      event_timestamp  quantity currency  \
# location
# Nigeria   2024-03-30 04:03:11.448971         5      USD
#
#                       checked_out_at   status
# location
# Nigeria   2024-03-30 04:11:11.449022  success

# %%
df["currency"].unique()
# Out:
# array(['NGN', 'USD', 'GBP'], dtype=object)

# %%
df.loc[call, "customer_id":"currency"].head(5)
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
#
#                                       order_id  event_id  \
# location
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# ...

# %%
currency_unique_times = df["currency"].value_counts()
currency_unique_times
# Out:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %%
currency_unique_times.plot(kind="bar")
# Out:
# <Axes: xlabel='currency'>

# %%
call = (df["customer_id"] == "916401c0-8d4c-40b3-91d3-2adf0d6d814f")

# %%
call2 = (df["customer_id"] == "916401c0-8d4c-40b3-91d3-2adf0d6d814f") & (df["status"] == "success")

# %%
df.loc[call2]
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
hi_customer = df.loc[call]

# %%
hi_customer["status"].value_counts()
# Out:
# status
# success    8
# Name: count, dtype: int64

# %%
call3 = (df["status"] == "failed")

# %%
df.loc[call3]
# Out:
#                                            customer_id  \
# location
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali              f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# ...

# %%
transaction_status = df["status"].value_counts()

# %%
transaction_status.plot(kind="bar")
# Out:
# <Axes: xlabel='status'>

# %%
status_by_currency = df.groupby(["status", "currency"])["currency"].count()
status_by_currency
# Out:
# status     currency
# cancelled  GBP         64324
#            NGN         57347
#            USD         67672
# failed     GBP         62813
#            NGN         65387
#            USD         68183
# success    GBP         64266
#            NGN         66146
#            USD         62182
# Name: currency, dtype: int64

# %%
status_by_currency.plot(kind="pie", a)
